# %% [markdown]
# <a href="https://colab.research.google.com/github/FX9919/Final-project-used-car-analysis/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_packages=""" numpy
pandas
matblptlib
seaborn"""
with open ('requrements.txt','w') as f:
  f.write(python_packages)
  print('done')
# Out:
# done
